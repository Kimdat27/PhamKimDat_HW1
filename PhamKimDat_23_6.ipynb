# %%
import folium
from geopy.geocoders import Nominatim
import osmnx as ox
import networkx as nx
ktx = "43 - 45 Nguyen Chi Thanh, Ho Chi Minh City"
geolocator = Nominatim(user_agent = "geoapi", timeout = 100)
td = geolocator.geocode(ktx)
td_ktx = (td.latitude,td.longitude)
m = folium.Map(location = td_ktx, zoom_start = 13)
folium.Marker(location = td_ktx, popup = "KTX").add_to(m)

ox.settings.timeout = 300
G = ox.graph_from_point(td_ktx, dist = 100, network_type = "walk")
stats = ox.basic_stats(G)
print(f"Số nút giao: {stats['n']}")
print(f"Số đoạn đường: {stats['m']}")
print(f"Chiều dài trung bình: {stats['street_length_avg']:.2f}m")
nodes, edges = ox.graph_to_gdfs(G)
folium.GeoJson(edges).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4c5d15a8d84e00accb8781393a55c30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4c5d15a8d84e00accb8781393a55c30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4c5d15a8d84e00accb8781393a55c30 = L.map(
#                 &quot;map_e4c5d15a8d84e00accb8781393a55c30&quot;,
#                 {
#                     center: [10.0767, 106.0074],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccb4040ced910a55a459dd87fb8aed65 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ccb4040ced910a55a459dd87fb8aed65.addTo(map_e4c5d15a8d84e00accb8781393a55c30);
#
#
#             var marker_32358ccd00a3e6e34b52ad56f9e51962 = L.marker(
#                 [10.067, 106.0077],
#                 {
# }
#             ).addTo(map_e4c5d15a8d84e00accb8781393a55c30);
#
#
#         var popup_e9019749c1506f75b969730c70ce02f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f7eed48b4cd41eea06412abacb5d978 = $(`&lt;div id=&quot;html_9f7eed48b4cd41eea06412abacb5d978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Có thể giao nhanh trong 10p&lt;/div&gt;`)[0];
#                 popup_e9019749c1506f75b969730c70ce02f7.setContent(html_9f7eed48b4cd41eea06412abacb5d978);
#
#
#
#         marker_32358ccd00a3e6e34b52ad56f9e51962.bindPopup(popup_e9019749c1506f75b969730c70ce02f7)
#         ;
#
#
#
#
#             marker_32358ccd00a3e6e34b52ad56f9e51962.bindTooltip(
#                 `&lt;div&gt;
#                      Khách hàng 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1863b5c96cf03e8871755fb02dbe8b71 = L.marker(
#                 [10.1073, 106.009],
#                 {
# }
#             ).addTo(map_e4c5d15a8d84e00accb8781393a55c30);
#
#
#         var popup_0c316c5947123e09cc74d4ed81192238 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfce940d0943d871c5f8f889e6930e9b = $(`&lt;div id=&quot;html_dfce940d0943d871c5f8f889e6930e9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Có thể giao nhanh trong 15p&lt;/div&gt;`)[0];
#                 popup_0c316c5947123e09cc74d4ed81192238.setContent(html_dfce940d0943d871c5f8f889e6930e9b);
#
#
#
#         marker_1863b5c96cf03e8871755fb02dbe8b71.bindPopup(popup_0c316c5947123e09cc74d4ed81192238)
#         ;
#
#
#
#
#             marker_1863b5c96cf03e8871755fb02dbe8b71.bindTooltip(
#                 `&lt;div&gt;
#                      Khách hàng 2
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5b78d48fd7e3b82a71d01dabbc78d5bb = L.marker(
#                 [10.1167, 106.01],
#                 {
# }
#             ).addTo(map_e4c5d15a8d84e00accb8781393a55c30);
#
#
#         var popup_3c5fb07ed4631d4d4dc7d9f1047edd97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45abda6fdd237674dbe691992cddee7e = $(`&lt;div id=&quot;html_45abda6fdd237674dbe691992cddee7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Có thể giao nhanh trong 30p&lt;/div&gt;`)[0];
#                 popup_3c5fb07ed4631d4d4dc7d9f1047edd97.setContent(html_45abda6fdd237674dbe691992cddee7e);
#
#
#
#         marker_5b78d48fd7e3b82a71d01dabbc78d5bb.bindPopup(popup_3c5fb07ed4631d4d4dc7d9f1047edd97)
#         ;
#
#
#
#
#             marker_5b78d48fd7e3b82a71d01dabbc78d5bb.bindTooltip(
#                 `&lt;div&gt;
#                      Khách hàng 3
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_e103f9632db6428508c1fb274bd561b2 = L.marker(
#                 [10.1575, 106.008],
#                 {
# }
#             ).addTo(map_e4c5d15a8d84e00accb8781393a55c30);
#
#
#         var popup_50e3b6aa309fc5e9c8c67b4df8906012 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fef507bad36d5d97137b3cfaf901789 = $(`&lt;div id=&quot;html_6fef507bad36d5d97137b3cfaf901789&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Có thể giao nhanh trong 60p&lt;/div&gt;`)[0];
#                 popup_50e3b6aa309fc5e9c8c67b4df8906012.setContent(html_6fef507bad36d5d97137b3cfaf901789);
#
#
#
#         marker_e103f9632db6428508c1fb274bd561b2.bindPopup(popup_50e

# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.3)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.30 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (26.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)
# Downloading osmnx-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.1.0
