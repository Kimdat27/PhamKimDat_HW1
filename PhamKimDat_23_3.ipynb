# %%
import folium
import random
from folium.plugins import HeatMap
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapi",timeout = 100)
center = geolocator.geocode("Ben Thanh Market, Ho Chi Minh City")
td = [center.latitude, center.longitude]
m = folium.Map(location=td, zoom_start = 13)
folium.Marker(td, popup = "Ben Thanh Market", icon=folium.Icon(color = "red")).add_to(m)
data=[]
for i in range(10):
  lat = center.latitude + random.uniform(0.001,0.01)
  lon = center.longitude + random.uniform(0.001,0.01)
  w = random.randint(1,10)
  data.append([lat, lon, w])

for i in range(30):
  lat1 = center.latitude - random.uniform(0.001,0.01)
  lon1 = center.longitude - random.uniform(0.001,0.01)
  w1 = random.randint(1,10)
  data.append([lat1, lon1, w1])
HeatMap(data).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11851/3364532523.py in <cell line: 0>()
#      11 ktx = [td_ktx.latitude, td_ktx.longitude]
#      12 nha = [td_nha.latitude, td_nha.longitude]
# ---> 13 G = ox.graph_from_point(nha, dist = 10000, network_type = "drive")
#      14 start_point = ox.distance.nearest_nodes(G, ktx[1],ktx[0])
#      15 end_point = ox.distance.nearest_nodes(G, nha[1],nha[0])
#
# /usr/local/lib/python3.12/dist-packages/osmnx/graph.py in graph_from_point(center_point, dist, dist_type, network_type, simplify, retain_all, truncate_by_edge, custom_filter)
#     199
#     200     # create a graph from the bounding box
# --> 201     G = graph_from_bbox(
#     202         bbox,
#     203         network_type=network_type,
#
# ...
